# %%
import pandas as pd

#column names from excel
xls = pd.ExcelFile('/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports/BLCA_ns_s_report.xlsx')
df1 = pd.read_excel(xls, 'Molecular function', skiprows=8, header =0)
df2 = pd.read_excel(xls, 'Biological pathway', skiprows=8, header =0)
df3 = pd.read_excel(xls, 'Transcription factor', skiprows=8, header =0)
df4 = pd.read_excel(xls, 'Clinical phenotype', skiprows=8, header =0)

file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/top10_BP.txt"
out_file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/top10_BP.sub"
file = pd.read_csv(file_name, sep='\t', header=None)
df_columns = list(df2.columns)
df_columns.append('cancer_sig')
df_columns
file.columns = df_columns
list(file.columns)
new = file['cancer_sig'].str.split('_', n = 1, expand = True)
file['cancer'] = new[0]
file['sig'] = new[1]
file['Biological_pathway'] = file['Biological pathway']
file['FDR_BH_p'] = file['BH method']
file[['Biological_pathway','cancer','sig','FDR_BH_p']].to_csv(out_file_name,index=False,header = True,sep="\t", mode ='w')

file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/bhfilter_BP.txt"
out_file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/bhfilter_BP.sub"
file = pd.read_csv(file_name, sep='\t', header=None)
df_columns = list(df2.columns)
df_columns.append('cancer_sig')
df_columns
file.columns = df_columns
list(file.columns)
new = file['cancer_sig'].str.split('_', n = 1, expand = True)
file['cancer'] = new[0]
file['sig'] = new[1]
file['Biological_pathway'] = file['Biological pathway']
file['FDR_BH_p'] = file['BH method']
file[['Biological_pathway','cancer','sig','FDR_BH_p']].to_csv(out_file_name,index=False,header = True,sep="\t", mode ='w')

# %%
import pandas as pd

#column names from excel
xls = pd.ExcelFile('/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports/BLCA_ns_s_report.xlsx')
df1 = pd.read_excel(xls, 'Molecular function', skiprows=8, header =0)
df2 = pd.read_excel(xls, 'Biological pathway', skiprows=8, header =0)
df3 = pd.read_excel(xls, 'Transcription factor', skiprows=8, header =0)
df4 = pd.read_excel(xls, 'Clinical phenotype', skiprows=8, header =0)

file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/top10_MF.txt"
out_file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/top10_MF.sub"
file = pd.read_csv(file_name, sep='\t', header=None)
df_columns = list(df1.columns)
df_columns.append('cancer_sig')
df_columns
file.columns = df_columns
list(file.columns)
new = file['cancer_sig'].str.split('_', n = 1, expand = True)
file['cancer'] = new[0]
file['sig'] = new[1]
file['Molecular_function'] = file['Molecular function']
file['FDR_BH_p'] = file['BH method']
file[['Molecular_function','cancer','sig','FDR_BH_p']].to_csv(out_file_name,index=False,header = True,sep="\t", mode ='w')


file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/bhfilter_MF.txt"
out_file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/bhfilter_MF.sub"
file = pd.read_csv(file_name, sep='\t', header=None)
df_columns = list(df1.columns)
df_columns.append('cancer_sig')
df_columns
file.columns = df_columns
list(file.columns)
new = file['cancer_sig'].str.split('_', n = 1, expand = True)
file['cancer'] = new[0]
file['sig'] = new[1]
file['Molecular_function'] = file['Molecular function']
file['FDR_BH_p'] = file['BH method']
file[['Molecular_function','cancer','sig','FDR_BH_p']].to_csv(out_file_name,index=False,header = True,sep="\t", mode ='w')

# %%
import pandas as pd

#column names from excel
xls = pd.ExcelFile('/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports/BLCA_ns_s_report.xlsx')
df1 = pd.read_excel(xls, 'Molecular function', skiprows=8, header =0)
df2 = pd.read_excel(xls, 'Biological pathway', skiprows=8, header =0)
df3 = pd.read_excel(xls, 'Transcription factor', skiprows=8, header =0)
df4 = pd.read_excel(xls, 'Clinical phenotype', skiprows=8, header =0)

file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/top10_TF.txt"
out_file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/top10_TF.sub"
file = pd.read_csv(file_name, sep='\t', header=None)
df_columns = list(df3.columns)
df_columns.append('cancer_sig')
df_columns
file.columns = df_columns
list(file.columns)
new = file['cancer_sig'].str.split('_', n = 1, expand = True)
file['cancer'] = new[0]
file['sig'] = new[1]
file['Transcription_factor'] = file['Transcription factor']
file['FDR_BH_p'] = file['BH method']
file[['Transcription_factor','cancer','sig','FDR_BH_p']].to_csv(out_file_name,index=False,header = True,sep="\t", mode ='w')
file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/bhfilter_TF.txt"
out_file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/bhfilter_TF.sub"
file = pd.read_csv(file_name, sep='\t', header=None)
df_columns = list(df3.columns)
df_columns.append('cancer_sig')
df_columns
file.columns = df_columns
list(file.columns)
new = file['cancer_sig'].str.split('_', n = 1, expand = True)
file['cancer'] = new[0]
file['sig'] = new[1]
file['Transcription_factor'] = file['Transcription factor']
file['FDR_BH_p'] = file['BH method']
file[['Transcription_factor','cancer','sig','FDR_BH_p']].to_csv(out_file_name,index=False,header = True,sep="\t", mode ='w')

# %%
import pandas as pd

#column names from excel
xls = pd.ExcelFile('/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports/BLCA_ns_s_report.xlsx')
df1 = pd.read_excel(xls, 'Molecular function', skiprows=8, header =0)
df2 = pd.read_excel(xls, 'Biological pathway', skiprows=8, header =0)
df3 = pd.read_excel(xls, 'Transcription factor', skiprows=8, header =0)
df4 = pd.read_excel(xls, 'Clinical phenotype', skiprows=8, header =0)

file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/top10_CP.txt"
out_file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/top10_CP.sub"
file = pd.read_csv(file_name, sep='\t', header=None)
df_columns = list(df4.columns)
df_columns.append('cancer_sig')
df_columns
file.columns = df_columns
list(file.columns)
new = file['cancer_sig'].str.split('_', n = 1, expand = True)
file['cancer'] = new[0]
file['sig'] = new[1]
file['Clinical_phenotype'] = file['Clinical phenotype']
file['FDR_BH_p'] = file['BH method']
file[['Clinical_phenotype','cancer','sig','FDR_BH_p']].to_csv(out_file_name,index=False,header = True,sep="\t", mode ='w')
     
file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/bhfilter_CP.txt"
out_file_name = "/home/workstation/Documents/Sarthak/gender_prognosis/analysis/bivariate_go/reports_all/bhfilter_CP.sub"
file = pd.read_csv(file_name, sep='\t', header=None)
df_columns = list(df4.columns)
df_columns.append('cancer_sig')
df_columns
file.columns = df_columns
list(file.columns)
new = file['cancer_sig'].str.split('_', n = 1, expand = True)
file['cancer'] = new[0]
file['sig'] = new[1]
file['Clinical_phenotype'] = file['Clinical phenotype']
file['FDR_BH_p'] = file['BH method']
file[['Clinical_phenotype','cancer','sig','FDR_BH_p']].to_csv(out_file_name,index=False,header = True,sep="\t", mode ='w')
